# %% [markdown]
# # California School Board Project

# %%
import pandas as pd

# %%
file1 = pd.read_excel(r"D:\BusyQA Assignments\Projects\California School\Cleaned Datasets\Cleaned_Suspension.xlsx") 
file2 = pd.read_excel(r"D:\BusyQA Assignments\Projects\California School\Cleaned Datasets\Cleaned_Expulsion.xlsx")

# %%
file1
# Out:
#        AcademicYear AggregateLevel  CountyCode  DistrictCode  SchoolCode  \
# 0           2016-17              S          19         64733      122382
# 1           2016-17              S          19         64733     6016448
# 2           2016-17              S          19         64733      133868
# 3           2016-17              S          19         64733     6019632
# 4           2016-17              S          19         64733     6016935
# ...             ...            ...         ...           ...         ...
# 244495      2016-17              D          54         71902           0
# 244496      2016-17              D          54         71969           0
# 244497      2016-17              D          54         76794           0
# 244498      2016-17              D          56         73759           0
# 244499      2016-17              D          57         72710           0
#
#          CountyName                  DistrictName  \
# ...

# %%
file2
# Out:
#        AcademicYear AggregateLevel  CountyCode  DistrictCode  SchoolCode  \
# 0           2016-17              D          19         10199           0
# 1           2016-17              D          19         64212           0
# 2           2016-17              D          19         64246           0
# 3           2016-17              D          19         64261           0
# 4           2016-17              D          19         64279           0
# ...             ...            ...         ...           ...         ...
# 244495      2016-17              D          56         72454           0
# 244496      2016-17              D          58         72769           0
# 244497      2016-17              D          58         72769           0
# 244498      2016-17              D          58         72769           0
# 244499      2016-17              D          58         72769           0
#
#          CountyName                            DistrictName       SchoolName  \
# ...

# %%
file1.columns
# Out:
# Index(['AcademicYear', 'AggregateLevel', 'CountyCode', 'DistrictCode',
#        'SchoolCode', 'CountyName', 'DistrictName', 'SchoolName', 'CharterYN',
#        'ReportingCategory', 'Cumulative Enrollment', 'Total Suspensions',
#        'Unduplicated Count of Students Suspended (Total)',
#        'Unduplicated Count of Students Suspended (Defiance-Only)',
#        'Suspension Rate (Total)', 'Suspension Count Violent Incident (Injury)',
#        'Suspension Count Violent Incident (No Injury)',
#        'Suspension Count Weapons Possession',
#        'Suspension Count Illicit Drug-Related',
#        'Suspension Count Defiance-Only', 'Suspension Count Other Reasons'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['AcademicYear', 'AggregateLevel', 'CountyCode', 'DistrictCode',
#        'SchoolCode', 'CountyName', 'DistrictName', 'SchoolName', 'CharterYN',
#        'ReportingCategory', 'Cumulative Enrollment', 'Total Expulsions',
#        'Unduplicated Count of Students Expelled (Total)',
#        'Unduplicated Count of Students Expelled (Defiance-Only)',
#        'Expulsion Rate (Total)', 'Expulsion Count Violent Incident (Injury)',
#        'Expulsion Count Violent Incident (No Injury)',
#        'Expulsion Count Weapons Possession',
#        'Expulsion Count Illicit Drug-Related', 'Expulsion Count Defiance-Only',
#        'Expulsion Count Other Reasons'],
#       dtype='object')

# %%
file12 = pd.merge(file1, file2,  how='inner', left_on=['DistrictCode', 'SchoolCode','CharterYN', 'ReportingCategory'], right_on = ['DistrictCode', 'SchoolCode','CharterYN', 'ReportingCategory'])
file12
# Out:
#        AcademicYear_x AggregateLevel_x  CountyCode_x  DistrictCode  \
# 0             2016-17                S            19         64733
# 1             2016-17                S            19         64733
# 2             2016-17                S            19         64733
# 3             2016-17                S            19         64733
# 4             2016-17                S            19         64733
# ...               ...              ...           ...           ...
# 245471        2016-17                D            54         71902
# 245472        2016-17                D            54         71969
# 245473        2016-17                D            54         76794
# 245474        2016-17                D            56         73759
# 245475        2016-17                D            57         72710
#
#         SchoolCode CountyName_x                DistrictName_x  \
# 0           122382  Los Angeles           Los Angeles Unified
# ...

# %%
file3 = pd.read_excel(r"D:\BusyQA Assignments\Projects\California School\Cleaned Datasets\Cleaned_Attendance.xlsx")
file4 = pd.read_excel(r"D:\BusyQA Assignments\Projects\California School\Cleaned Datasets\Cleaned_Free Meals.xlsx")
file5 = pd.read_excel(r"D:\BusyQA Assignments\Projects\California School\Cleaned Datasets\Cleaned_Tests.xlsx")

# %%
file3
# Out:
#        AcademicYear AggregateLevel  CountyCode  DistrictCode  SchoolCode  \
# 0           2016-17              D          19         64345           0
# 1           2016-17              D          19         64394           0
# 2           2016-17              D          19         64485           0
# 3           2016-17              D          19         64485           0
# 4           2016-17              D          19         64501           0
# ...             ...            ...         ...           ...         ...
# 180064      2016-17              S          19         64733      102137
# 180065      2016-17              S          19         64733      115782
# 180066      2016-17              S          19         64733      133736
# 180067      2016-17              S          19         64733     6020044
# 180068      2016-17              S          19         64733      115782
#
#          CountyName                   DistrictName  \
# ...

# %%
file12.columns
# Out:
# Index(['AcademicYear_x', 'AggregateLevel_x', 'CountyCode_x', 'DistrictCode',
#        'SchoolCode', 'CountyName_x', 'DistrictName_x', 'SchoolName_x',
#        'CharterYN', 'ReportingCategory', 'Cumulative Enrollment_x',
#        'Total Suspensions', 'Unduplicated Count of Students Suspended (Total)',
#        'Unduplicated Count of Students Suspended (Defiance-Only)',
#        'Suspension Rate (Total)', 'Suspension Count Violent Incident (Injury)',
#        'Suspension Count Violent Incident (No Injury)',
#        'Suspension Count Weapons Possession',
#        'Suspension Count Illicit Drug-Related',
#        'Suspension Count Defiance-Only', 'Suspension Count Other Reasons',
#        'AcademicYear_y', 'AggregateLevel_y', 'CountyCode_y', 'CountyName_y',
#        'DistrictName_y', 'SchoolName_y', 'Cumulative Enrollment_y',
#        'Total Expulsions', 'Unduplicated Count of Students Expelled (Total)',
#        'Unduplicated Count of Students Expelled (Defiance-Only)',
# ...

# %%
file3.columns
# Out:
# Index(['AcademicYear', 'AggregateLevel', 'CountyCode', 'DistrictCode',
#        'SchoolCode', 'CountyName', 'DistrictName', 'SchoolName', 'CharterYN',
#        'ReportingCategory', 'CumulativeEnrollment',
#        'ChronicAbsenteeismEligibleCumulativeEnrollment',
#        'ChronicAbsenteeismCount', 'ChronicAbsenteeismRate'],
#       dtype='object')

# %%
file123 = pd.merge(file12, file3,  how='inner', left_on=['DistrictCode', 'SchoolCode','CharterYN', 'ReportingCategory'], right_on = ['DistrictCode', 'SchoolCode','CharterYN', 'ReportingCategory'])
file123
# Out:
#        AcademicYear_x AggregateLevel_x  CountyCode_x  DistrictCode  \
# 0             2016-17                S            19         64733
# 1             2016-17                S            19         64733
# 2             2016-17                S            19         64733
# 3             2016-17                S            19         64733
# 4             2016-17                S            19         64733
# ...               ...              ...           ...           ...
# 137711        2016-17                D            54         71902
# 137712        2016-17                D            54         71969
# 137713        2016-17                D            54         76794
# 137714        2016-17                D            56         73759
# 137715        2016-17                D            57         72710
#
#         SchoolCode CountyName_x                DistrictName_x  \
# 0           122382  Los Angeles           Los Angeles Unified
# ...

# %%
file4
# Out:
#     Academic Year  County Code  District Code  School Code County Name  \
# 0       2016-2017            1          10017       123968     Alameda
# 1       2016-2017            1          10017      6002000     Alameda
# 2       2016-2017            1          61259       111476     Alameda
# 3       2016-2017            1          61259       115592     Alameda
# 4       2016-2017            1          61259       129403     Alameda
# ..            ...          ...            ...          ...         ...
# 98      2016-2017           44          69799      6049829  Santa Cruz
# 99      2016-2017           51          71464      5130125      Sutter
# 100     2016-2017           54          72256      5430269      Tulare
# 101     2016-2017           54          75523       116590      Tulare
# 102     2016-2017           58          10587      5830112        Yuba
#
#                           District Name  \
# 0    Alameda County Office of Education
# ...

# %%
file4.columns
# Out:
# Index(['Academic Year', 'County Code', 'District Code', 'School Code',
#        'County Name', 'District Name', 'School Name', 'District Type',
#        'School Type', 'Educational Option Type', 'NSLP Provision Status',
#        'Charter School (Y/N)', 'Charter School Number', 'Charter Funding Type',
#        'IRC', 'Low Grade', 'High Grade', 'Enrollment (K-12)',
#        'Free Meal Count (K-12)', 'Percent (%) Eligible Free (K-12)',
#        'FRPM Count (K-12)', 'Percent (%) Eligible FRPM (K-12)',
#        'Enrollment (Ages 5-17)', 'Free Meal Count (Ages 5-17)',
#        'Percent (%) Eligible Free (Ages 5-17)', 'FRPM Count (Ages 5-17)',
#        'Percent (%) Eligible FRPM (Ages 5-17)',
#        '2016-17 CALPADS Fall 1 Certification Status'],
#       dtype='object')

# %%
file1234 = pd.merge(file123, file4,  how='inner', left_on=['DistrictCode','SchoolCode'], right_on = ['District Code', 'School Code'])
file1234
# Out:
#     AcademicYear_x AggregateLevel_x  CountyCode_x  DistrictCode  SchoolCode  \
# 0          2016-17                S            19         64733      117937
# 1          2016-17                S            19         64733      117937
# 2          2016-17                S            19         64733      117937
# 3          2016-17                S            19         64733      117937
# 4          2016-17                S            19         64733      117937
# ..             ...              ...           ...           ...         ...
# 945        2016-17                S            37         68338      101345
# 946        2016-17                S            37         68338      101345
# 947        2016-17                S            37         68338      101345
# 948        2016-17                S            37         68338      101345
# 949        2016-17                S            37         68338      101345
#
# ...

# %%
file1234.columns
# Out:
# Index(['AcademicYear_x', 'AggregateLevel_x', 'CountyCode_x', 'DistrictCode',
#        'SchoolCode', 'CountyName_x', 'DistrictName_x', 'SchoolName_x',
#        'CharterYN', 'ReportingCategory', 'Cumulative Enrollment_x',
#        'Total Suspensions', 'Unduplicated Count of Students Suspended (Total)',
#        'Unduplicated Count of Students Suspended (Defiance-Only)',
#        'Suspension Rate (Total)', 'Suspension Count Violent Incident (Injury)',
#        'Suspension Count Violent Incident (No Injury)',
#        'Suspension Count Weapons Possession',
#        'Suspension Count Illicit Drug-Related',
#        'Suspension Count Defiance-Only', 'Suspension Count Other Reasons',
#        'AcademicYear_y', 'AggregateLevel_y', 'CountyCode_y', 'CountyName_y',
#        'DistrictName_y', 'SchoolName_y', 'Cumulative Enrollment_y',
#        'Total Expulsions', 'Unduplicated Count of Students Expelled (Total)',
#        'Unduplicated Count of Students Expelled (Defiance-Only)',
# ...

# %%
file5
# Out:
#               CDSCode AcademicYear AggregateLevel  County Code  District Code  \
# 0       4100410000000      2016-17       District            4          10041
# 1       4100410000000      2016-17       District            4          10041
# 2       4614240000000      2016-17       District            4          61424
# 3       4614240000000      2016-17       District            4          61424
# 4       4614240000000      2016-17       District            4          61424
# ...               ...          ...            ...          ...            ...
# 32378  55105530000000      2016-17       District           55          10553
# 32379  55105530000000      2016-17       District           55          10553
# 32380  55105530000000      2016-17       District           55          10553
# 32381  57105790000000      2016-17       District           57          10579
# 32382  58105870000000      2016-17       District           58          10587
#
# ...

# %%
file12345 = pd.merge(file1234, file5,  how='inner', left_on=['DistrictCode', 'ReportingCategory'], right_on = ['District Code', 'Student Group Reporting Category'])
file12345
# Out:
# C:\Users\reeba\AppData\Local\Temp\ipykernel_15976\2156430734.py:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'AggregateLevel_x', 'AcademicYear_x'} in the result is deprecated and will raise a MergeError in a future version.
#   file12345 = pd.merge(file1234, file5,  how='inner', left_on=['DistrictCode', 'ReportingCategory'], right_on = ['District Code', 'Student Group Reporting Category'])
#      AcademicYear_x AggregateLevel_x  CountyCode_x  DistrictCode  SchoolCode  \
# 0           2016-17                S            19         64733      117937
# 1           2016-17                S            19         64733      117937
# 2           2016-17                S            19         64733      117937
# 3           2016-17                S            19         64733      117937
# 4           2016-17                S            19         64733      122630
# ...             ...              ...           ...           ...         ...
# ...

# %%
file12345.to_excel('D:\BusyQA Assignments\Projects\California School\Cleaned Datasets\Analytical Dataset.xlsx')

# %% [markdown]
# ## Thank you!
